# %% [markdown]
# # **Producto Integrador de Aprendizaje**
# ---
# Tema: **Entrenamiento de una CNN usando CIFAR-100**\
# Inteligencia Artificial; IB
#
#
# > 1877436, Jesús Emmanuel Guerrero Cortez \
# > 1943543, Haziel Jair Sánchez Barrón \
# > 1378118, Víctor Manuel Castañeda de León \
# > 1841262, Bryan David Garrido \
# > 1799686, Jesús Quezada Oviedo

# %%
import tensorflow as tf
#Importación de base de trabajo y librerías 
from tensorflow.keras import datasets, layers, models
from keras.models import Model
from keras.layers import Dense, Dropout, Flatten, Activation
from tensorflow.keras.applications.inception_v3 import InceptionV3
#VGG16 con fine-tuning, aunque puede ser empleado con cualquier modelo
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score
#____________________________________________________________________#
from datetime import datetime
import pandas as pd
import numpy as np
import pytz
import random
import matplotlib.pyplot as plt

#Arreglo se usará como registro, aunque bien se podrían enviar los valores a archivo csv.
historyarray = [0]

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar100.load_data(label_mode='coarse')
#Normalización (abajo) e importación del data set CIFAR100 (arriba), con conjuntos de prueba y entrenamiento.
train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 3s 0us/step
# 169017344/169001437 [==============================] - 3s 0us/step

# %%
#Inicialmente, optamos por eliminar el arreglo de strings para etiquetas, puesto que equivaldría a 100 clases.
#Para evitar la fatiga de copiar y pegar, se procesaron los atributos a partir de un archivo csv (sep. por coma, tipo str); creado.
#Al final, para aumentar exactitud, se redujo la ultima capa profunda a 20 nodos, o superclases.
#Valores de shape de set de entrenamiento se usarán al trabajar con modelo de transfer learning.

'''
CIFAR100_attributes = pd.read_csv('https://pastebin.com/raw/qgDaNggt', sep=',', header=None).astype(str).values.tolist()[0]

'''
Coarse_labels = ['aquatic_mammals', 'fish', 'flowers', 'food_containers', 'fruit_and_vegetables', 
                'household_electrical_devices', 'household_furniture', 'insects', 'large_carnivores', 
                'large_man-made_outdoor_things', 'large_natural_outdoor_scenes', 'large_omnivores_and_herbivores', 
                'medium_mammals', 'non-insect_invertebrates', 'people', 'reptiles', 'small_mammals', 'trees', 'vehicles_1', 'vehicles_2']

data_size, img_rows, img_cols, img_channels = train_images.shape

plt.figure(figsize=(10,10))
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(Coarse_labels[train_labels[i][0]])
plt.show()

# %%
#Imágenes a RGB, 32x32x(3_canales); capas superficiales
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(Dropout(0.20))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(Dropout(0.20))
model.add(layers.Conv2D(256, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

# %%
#Modelo de capas profundas
model.add(layers.Flatten())
model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(20))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d_3 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  dropout_3 (Dropout)         (None, 15, 15, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 13, 13, 64)        18496
#
#  conv2d_6 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  dropout_4 (Dropout)         (None, 5, 5, 64)          0
#
#  conv2d_7 (Conv2D)           (None, 3, 3, 256)         147712
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  dropout_5 (Dropout)         (None, 1, 1, 256)         0
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 1024)              263168
#
#  dense_5 (Dense)             (None, 256)               262400
#
#  dense_6 (Dense)             (None, 64)                16448
#
#  dense_7 (Dense)             (None, 20)                1300
#
# =================================================================
# Total params: 747,348
# Trainable params: 747,348
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Esta celda tiene por intención guardar el mejor modelo a partir del peso de sus características; solo tiene utilidad en fine-tuning
# ModelCheckpoint callback - guardar los mejores pesos (weights).
tl_checkpoint_1 = ModelCheckpoint(filepath='tl_model_v1.weights.best.hdf5',
                                  save_best_only=True,
                                  verbose=1)

# Si no existe cambio en la perdida durante la validación, se detiene.
early_stop = EarlyStopping(monitor='val_loss',
                           patience=10,
                           restore_best_weights=True,
                           mode='min')

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))

#Aceleración con GPU (demasiado útil). Fundamentos disponibles en: https://colab.research.google.com/notebooks/gpu.ipynb#scrollTo=sXnDmXR7RDr2

tf.keras.optimizers.Adagrad(
    learning_rate=0.00005, initial_accumulator_value=0.1, epsilon=1e-07, name="Adagrad"
)

tf.keras.optimizers.Adadelta(
    learning_rate=0.001, rho=0.95, epsilon=1e-07, name="Adadelta"
)

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

def train_model(model, epochs = 10, steps_per_epoch = 2, validation_steps = 1):
  history = model.fit(train_images, train_labels, epochs = epochs, steps_per_epoch = steps_per_epoch, validation_data = (test_images, test_labels), validation_steps = validation_steps, callbacks=[tl_checkpoint_1, early_stop])
  return(history)
# Out:
# Found GPU at: /device:GPU:0

# %%
SIMPLE_MODEL_history = train_model(model, 30, 150, 20)
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
# Out:
# Epoch 1/30
# 150/150 [==============================] - ETA: 0s - loss: 2.7998 - accuracy: 0.1164
# Epoch 00001: val_loss improved from inf to 2.60042, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 7s 41ms/step - loss: 2.7998 - accuracy: 0.1164 - val_loss: 2.6004 - val_accuracy: 0.1955
# Epoch 2/30
# 149/150 [============================>.] - ETA: 0s - loss: 2.5092 - accuracy: 0.2196
# Epoch 00002: val_loss improved from 2.60042 to 2.39196, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 5s 35ms/step - loss: 2.5090 - accuracy: 0.2197 - val_loss: 2.3920 - val_accuracy: 0.2596
# Epoch 3/30
# 149/150 [============================>.] - ETA: 0s - loss: 2.3224 - accuracy: 0.2798
# Epoch 00003: val_loss improved from 2.39196 to 2.21928, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 5s 35ms/step - loss: 2.3220 - accuracy: 0.2797 - val_loss: 2.2193 - val_accuracy: 0.3128
# Epoch 4/30
# 149/150 [============================>.] - ETA: 0s - loss: 2.2044 - accuracy: 0.3161
# Epoch 00004: val_loss improved from 2.21928 to 2.12776, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 5s 35ms/step - loss: 2.2042 - accuracy: 0.3162 - val_loss: 2.1278 - val_accuracy: 0.3366
# Epoch 5/30
# 149/150 [============================>.] - ETA: 0s - loss: 2.1162 - accuracy: 0.3424
# Epoch 00005: val_loss improved from 2.12776 to 2.07102, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 5s 35ms/step - loss: 2.1155 - accuracy: 0.3426 - val_loss: 2.0710 - val_accuracy: 0.3577
# Epoch 6/30
# 149/150 [============================>.] - ETA: 0s - loss: 2.0360 - accuracy: 0.3676
# Epoch 00006: val_loss improved from 2.07102 to 1.98087, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 5s 35ms/step - loss: 2.0362 - accuracy: 0.3677 - val_loss: 1.9809 - val_accuracy: 0.3830
# Epoch 7/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.9733 - accuracy: 0.3855
# Epoch 00007: val_loss improved from 1.98087 to 1.92104, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 5s 35ms/step - loss: 1.9732 - accuracy: 0.3855 - val_loss: 1.9210 - val_accuracy: 0.4030
# Epoch 8/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.9141 - accuracy: 0.4051
# Epoch 00008: val_loss improved from 1.92104 to 1.87763, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 5s 35ms/step - loss: 1.9142 - accuracy: 0.4050 - val_loss: 1.8776 - val_accuracy: 0.4192
# Epoch 9/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.8676 - accuracy: 0.4190
# Epoch 00009: val_loss improved from 1.87763 to 1.84383, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 5s 35ms/step - loss: 1.8678 - accuracy: 0.4191 - val_loss: 1.8438 - val_accuracy: 0.4253
# Epoch 10/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.8177 - accuracy: 0.4356
# Epoch 00010: val_loss improved from 1.84383 to 1.77800, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 5s 35ms/step - loss: 1.8181 - accuracy: 0.4357 - val_loss: 1.7780 - val_accuracy: 0.4454
# Epoch 11/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.7760 - accuracy: 0.4455
# Epoch 00011: val_loss improved from 1.77800 to 1.74060, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 5s 35ms/step - loss: 1.7759 - accuracy: 0.4454 - val_loss: 1.7406 - val_accuracy: 0.4579
# Epoch 12/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.7437 - accuracy: 0.4550
# Epoch 00012: val_loss did not improve from 1.74060
# 150/150 [==============================] - 5s 34ms/step - loss: 1.7438 - accuracy: 0.4550 - val_loss: 1.8512 - val_accuracy: 0.4250
# Epoch 13/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.7174 - accuracy: 0.4627
# Epoch 00013: val_loss improved from 1.74060 to 1.71404, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 5s 34ms/step - loss: 1.7171 - accuracy: 0.4629 - val_loss: 1.7140 - val_accuracy: 0.4653
# Epoch 14/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.6799 - accuracy: 0.4736
# Epoch 00014: val_loss did not improve from 1.71404
# 150/150 [==============================] - 5s 34ms/step - loss: 1.6794 - accuracy: 0.4738 - val_loss: 1.7920 - val_accuracy: 0.4484
# Epoch 15/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.6556 - accuracy: 0.4810
# Epoch 00015: val_loss improved from 1.71404 to 1.70013, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 5s 35ms/step - loss: 1.6556 - accuracy: 0.4809 - val_loss: 1.7001 - val_accuracy: 0.4656
# Epoch 16/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.6236 - accuracy: 0.4906
# Epoch 00016: val_loss did not improve from 1.70013
# 150/150 [==============================] - 5s 34ms/step - loss: 1.6240 - accuracy: 0.4905 - val_loss: 1.7043 - val_accuracy: 0.4668
# Epoch 17/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.5920 - accuracy: 0.5011
# Epoch 00017: val_loss improved from 1.70013 to 1.67518, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 5s 35ms/step - loss: 1.5920 - accuracy: 0.5010 - val_loss: 1.6752 - val_accuracy: 0.4761
# Epoch 18/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.5751 - accuracy: 0.5033
# Epoch 00018: val_loss improved from 1.67518 to 1.63111, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 5s 35ms/step - loss: 1.5753 - accuracy: 0.5032 - val_loss: 1.6311 - val_accuracy: 0.4847
# Epoch 19/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.5471 - accuracy: 0.5124
# Epoch 00019: val_loss did not improve from 1.63111
# 150/150 [==============================] - 5s 34ms/step - loss: 1.5474 - accuracy: 0.5123 - val_loss: 1.6530 - val_accuracy: 0.4828
# Epoch 20/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.5240 - accuracy: 0.5177
# Epoch 00020: val_loss did not improve from 1.63111
# 150/150 [==============================] - 5s 34ms/step - loss: 1.5242 - accuracy: 0.5177 - val_loss: 1.6533 - val_accuracy: 0.4837
# Epoch 21/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.5133 - accuracy: 0.5218
# Epoch 00021: val_loss improved from 1.63111 to 1.59632, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 5s 34ms/step - loss: 1.5130 - accuracy: 0.5219 - val_loss: 1.5963 - val_accuracy: 0.5025
# Epoch 22/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.4940 - accuracy: 0.5271
# Epoch 00022: val_loss did not improve from 1.59632
# 150/150 [==============================] - 5s 34ms/step - loss: 1.4933 - accuracy: 0.5272 - val_loss: 1.6279 - val_accuracy: 0.4974
# Epoch 23/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.4781 - accuracy: 0.5318
# Epoch 00023: val_loss improved from 1.59632 to 1.58000, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 5s 34ms/step - loss: 1.4783 - accuracy: 0.5317 - val_loss: 1.5800 - val_accuracy: 0.5074
# Epoch 24/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.4545 - accuracy: 0.5380
# Epoch 00024: val_loss did not improve from 1.58000
# 150/150 [==============================] - 5s 34ms/step - loss: 1.4545 - accuracy: 0.5379 - val_loss: 1.5867 - val_accuracy: 0.5098
# Epoch 25/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.4368 - accuracy: 0.5440
# Epoch 00025: val_loss did not improve from 1.58000
# 150/150 [==============================] - 5s 34ms/step - loss: 1.4370 - accuracy: 0.5441 - val_loss: 1.5837 - val_accuracy: 0.5061
# Epoch 26/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.4237 - accuracy: 0.5494
# Epoch 00026: val_loss did not improve from 1.58000
# 150/150 [==============================] - 5s 34ms/step - loss: 1.4242 - accuracy: 0.5493 - val_loss: 1.6138 - val_accuracy: 0.5001
# Epoch 27/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.4025 - accuracy: 0.5543
# Epoch 00027: val_loss improved from 1.58000 to 1.57559, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 5s 34ms/step - loss: 1.4025 - accuracy: 0.5545 - val_loss: 1.5756 - val_accuracy: 0.5107
# Epoch 28/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.3982 - accuracy: 0.5543
# Epoch 00028: val_loss did not improve from 1.57559
# 150/150 [==============================] - 5s 34ms/step - loss: 1.3984 - accuracy: 0.5542 - val_loss: 1.5812 - val_accuracy: 0.5096
# Epoch 29/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.3705 - accuracy: 0.5635
# Epoch 00029: val_loss did not improve from 1.57559
# 150/150 [==============================] - 5s 33ms/step - loss: 1.3705 - accuracy: 0.5634 - val_loss: 1.5826 - val_accuracy: 0.5094
# Epoch 30/30
# 149/150 [============================>.] - ETA: 0s - loss: 1.3621 - accuracy: 0.5669
# Epoch 00030: val_loss improved from 1.57559 to 1.56199, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 5s 35ms/step - loss: 1.3614 - accuracy: 0.5672 - val_loss: 1.5620 - val_accuracy: 0.5148
# 313/313 - 2s - loss: 1.5620 - accuracy: 0.5148 - 2s/epoch - 5ms/step

# %%
# Transfer learning: VGG16 entrenado usando ImageNet; se usa sin su top layer.
def init_VGG16_model(summary):
  VGG16_MODEL=tf.keras.applications.VGG16(input_shape=(img_rows, img_cols, img_channels), include_top=False, weights='imagenet')

  # Habilitar conv layers
  VGG16_MODEL.trainable=True

  dropout_layer = tf.keras.layers.Dropout(rate = 0.25)
  global_average_layer = tf.keras.layers.GlobalAveragePooling2D()

  # Se sobrepone la top layer de CIFAR100 (dense de 20 neuronas, activación softmax para daterminación de clases = 1.0) junto con el model sequential de la red de transferencia
  prediction_layer = tf.keras.layers.Dense(len(Coarse_labels),activation='sigmoid')
  model = tf.keras.Sequential([VGG16_MODEL, dropout_layer, global_average_layer, prediction_layer])

  model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.000001), loss=tf.keras.losses.sparse_categorical_crossentropy, metrics=["accuracy"])
  if summary: 
    model.summary()
  return model

VGG16_MODEL = init_VGG16_model(summary = True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 58900480/58889256 [==============================] - 1s 0us/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 1, 1, 512)         14714688
#
#  dropout_6 (Dropout)         (None, 1, 1, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense_8 (Dense)             (None, 20)                10260
#
# =================================================================
# Total params: 14,724,948
# Trainable params: 14,724,948
# Non-trainable params: 0
# _________________________________________________________________

# %%
VGG16_MODEL_history = train_model(VGG16_MODEL, 15, 400, 40)
test_loss_VGG16, test_acc_VGG16 = model.evaluate(test_images, test_labels, verbose=2)
# Out:
# Epoch 1/15
# 400/400 [==============================] - ETA: 0s - loss: 3.0017 - accuracy: 0.1060
# Epoch 00001: val_loss did not improve from 1.56199
# 400/400 [==============================] - 56s 132ms/step - loss: 3.0017 - accuracy: 0.1060 - val_loss: 2.5828 - val_accuracy: 0.2302
# Epoch 2/15
# 400/400 [==============================] - ETA: 0s - loss: 2.5053 - accuracy: 0.2375
# Epoch 00002: val_loss did not improve from 1.56199
# 400/400 [==============================] - 50s 126ms/step - loss: 2.5053 - accuracy: 0.2375 - val_loss: 2.2070 - val_accuracy: 0.3260
# Epoch 3/15
# 400/400 [==============================] - ETA: 0s - loss: 2.2239 - accuracy: 0.3122
# Epoch 00003: val_loss did not improve from 1.56199
# 400/400 [==============================] - 50s 125ms/step - loss: 2.2239 - accuracy: 0.3122 - val_loss: 1.9943 - val_accuracy: 0.3860
# Epoch 4/15
# 400/400 [==============================] - ETA: 0s - loss: 2.0489 - accuracy: 0.3636
# Epoch 00004: val_loss did not improve from 1.56199
# 400/400 [==============================] - 50s 125ms/step - loss: 2.0489 - accuracy: 0.3636 - val_loss: 1.8646 - val_accuracy: 0.4285
# Epoch 5/15
# 400/400 [==============================] - ETA: 0s - loss: 1.9195 - accuracy: 0.4006
# Epoch 00005: val_loss did not improve from 1.56199
# 400/400 [==============================] - 50s 126ms/step - loss: 1.9195 - accuracy: 0.4006 - val_loss: 1.7601 - val_accuracy: 0.4569
# Epoch 6/15
# 400/400 [==============================] - ETA: 0s - loss: 1.8232 - accuracy: 0.4333
# Epoch 00006: val_loss did not improve from 1.56199
# 400/400 [==============================] - 50s 126ms/step - loss: 1.8232 - accuracy: 0.4333 - val_loss: 1.6845 - val_accuracy: 0.4784
# Epoch 7/15
# 400/400 [==============================] - ETA: 0s - loss: 1.7508 - accuracy: 0.4531
# Epoch 00007: val_loss did not improve from 1.56199
# 400/400 [==============================] - 50s 126ms/step - loss: 1.7508 - accuracy: 0.4531 - val_loss: 1.6282 - val_accuracy: 0.4928
# Epoch 8/15
# 400/400 [==============================] - ETA: 0s - loss: 1.6889 - accuracy: 0.4701
# Epoch 00008: val_loss did not improve from 1.56199
# 400/400 [==============================] - 50s 126ms/step - loss: 1.6889 - accuracy: 0.4701 - val_loss: 1.5782 - val_accuracy: 0.5093
# Epoch 9/15
# 400/400 [==============================] - ETA: 0s - loss: 1.6377 - accuracy: 0.4869
# Epoch 00009: val_loss improved from 1.56199 to 1.53964, saving model to tl_model_v1.weights.best.hdf5
# 400/400 [==============================] - 51s 126ms/step - loss: 1.6377 - accuracy: 0.4869 - val_loss: 1.5396 - val_accuracy: 0.5216
# Epoch 10/15
# 400/400 [==============================] - ETA: 0s - loss: 1.5928 - accuracy: 0.5008
# Epoch 00010: val_loss improved from 1.53964 to 1.51240, saving model to tl_model_v1.weights.best.hdf5
# 400/400 [==============================] - 51s 127ms/step - loss: 1.5928 - accuracy: 0.5008 - val_loss: 1.5124 - val_accuracy: 0.5296
# Epoch 11/15
# 400/400 [==============================] - ETA: 0s - loss: 1.5570 - accuracy: 0.5087
# Epoch 00011: val_loss improved from 1.51240 to 1.48173, saving model to tl_model_v1.weights.best.hdf5
# 400/400 [==============================] - 51s 126ms/step - loss: 1.5570 - accuracy: 0.5087 - val_loss: 1.4817 - val_accuracy: 0.5372
# Epoch 12/15
# 400/400 [==============================] - ETA: 0s - loss: 1.5221 - accuracy: 0.5204
# Epoch 00012: val_loss improved from 1.48173 to 1.45575, saving model to tl_model_v1.weights.best.hdf5
# 400/400 [==============================] - 51s 127ms/step - loss: 1.5221 - accuracy: 0.5204 - val_loss: 1.4557 - val_accuracy: 0.5459
# Epoch 13/15
# 400/400 [==============================] - ETA: 0s - loss: 1.4875 - accuracy: 0.5304
# Epoch 00013: val_loss improved from 1.45575 to 1.43131, saving model to tl_model_v1.weights.best.hdf5
# 400/400 [==============================] - 51s 127ms/step - loss: 1.4875 - accuracy: 0.5304 - val_loss: 1.4313 - val_accuracy: 0.5496
# Epoch 14/15
# 400/400 [==============================] - ETA: 0s - loss: 1.4663 - accuracy: 0.5363
# Epoch 00014: val_loss improved from 1.43131 to 1.41169, saving model to tl_model_v1.weights.best.hdf5
# 400/400 [==============================] - 51s 127ms/step - loss: 1.4663 - accuracy: 0.5363 - val_loss: 1.4117 - val_accuracy: 0.5593
# Epoch 15/15
# 400/400 [==============================] - ETA: 0s - loss: 1.4385 - accuracy: 0.5475
# Epoch 00015: val_loss improved from 1.41169 to 1.39317, saving model to tl_model_v1.weights.best.hdf5
# 400/400 [==============================] - 51s 127ms/step - loss: 1.4385 - accuracy: 0.5475 - val_loss: 1.3932 - val_accuracy: 0.5626
# 313/313 - 2s - loss: 1.5620 - accuracy: 0.5148 - 2s/epoch - 5ms/step

# %%
# Transfer learning: VGG16 entrenado usando ImageNet; se usa sin su top layer, pero se añade fine-tuning (ver documento)
def init_VGG16_model_finetuning(summary, fine_tune=0):
  VGG16_MODEL_FT=tf.keras.applications.VGG16(input_shape=(img_rows, img_cols, img_channels), include_top=False, weights='imagenet')

  # Define cuántas capas se congelan durante el entrenamiento. Las capas de la base convolucional 
  # pasan de ser entrenables a no entrenables dependiendo del valor de fine-tuning.
  if fine_tune > 0:
    for layer in VGG16_MODEL_FT.layers[:-fine_tune]:
      layer.trainable = False
  else:
    for layer in VGG16_MODEL_FT.layers:
      layer.trainable = False

  top_model = VGG16_MODEL_FT.output
  top_model = Flatten(name="flatten")(top_model)
  top_model = Dense(4096, activation='relu')(top_model)
  top_model = Dense(1072, activation='relu')(top_model)
  top_model = Dropout(0.2)(top_model)

  # Se sobrepone la top layer de CIFAR100 (dense de 20 neuronas, activación softmax para 
  # determinación de clases = 1.0) junto con el model sequential de la red de transferencia
  prediction_layer = Dense(len(Coarse_labels), activation='softmax')(top_model)
  model = tf.keras.Model(inputs=VGG16_MODEL_FT.input, outputs=prediction_layer)

  model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.0001), loss=tf.keras.losses.sparse_categorical_crossentropy, metrics=["accuracy"])
  if summary: 
    model.summary()
  return model

VGG16_MODEL_FT = init_VGG16_model_finetuning(summary = True, fine_tune=4)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_15 (Dense)            (None, 4096)              2101248
#
#  dense_16 (Dense)            (None, 1072)              4391984
#
#  dropout_9 (Dropout)         (None, 1072)              0
#
#  dense_17 (Dense)            (None, 20)                21460
#
# =================================================================
# Total params: 21,229,380
# Trainable params: 13,594,116
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
VGG16_MODEL_FT_history = train_model(VGG16_MODEL_FT, 15, 100, 10)
test_loss_VGG16_FT, test_acc_VGG16_FT = model.evaluate(test_images, test_labels, verbose=1)
# Out:
# Epoch 1/15
# 100/100 [==============================] - ETA: 0s - loss: 1.9070 - accuracy: 0.4053
# Epoch 00001: val_loss did not improve from 1.39317
# 100/100 [==============================] - 35s 281ms/step - loss: 1.9070 - accuracy: 0.4053 - val_loss: 1.5835 - val_accuracy: 0.4983
# Epoch 2/15
# 100/100 [==============================] - ETA: 0s - loss: 1.4546 - accuracy: 0.5358
# Epoch 00002: val_loss did not improve from 1.39317
# 100/100 [==============================] - 19s 194ms/step - loss: 1.4546 - accuracy: 0.5358 - val_loss: 1.3943 - val_accuracy: 0.5552
# Epoch 3/15
# 100/100 [==============================] - ETA: 0s - loss: 1.2806 - accuracy: 0.5924
# Epoch 00003: val_loss improved from 1.39317 to 1.33564, saving model to tl_model_v1.weights.best.hdf5
# 100/100 [==============================] - 20s 204ms/step - loss: 1.2806 - accuracy: 0.5924 - val_loss: 1.3356 - val_accuracy: 0.5738
# Epoch 4/15
# 100/100 [==============================] - ETA: 0s - loss: 1.1371 - accuracy: 0.6361
# Epoch 00004: val_loss improved from 1.33564 to 1.31548, saving model to tl_model_v1.weights.best.hdf5
# 100/100 [==============================] - 20s 199ms/step - loss: 1.1371 - accuracy: 0.6361 - val_loss: 1.3155 - val_accuracy: 0.5847
# Epoch 5/15
# 100/100 [==============================] - ETA: 0s - loss: 1.0109 - accuracy: 0.6745
# Epoch 00005: val_loss did not improve from 1.31548
# 100/100 [==============================] - 20s 198ms/step - loss: 1.0109 - accuracy: 0.6745 - val_loss: 1.3399 - val_accuracy: 0.5895
# Epoch 6/15
# 100/100 [==============================] - ETA: 0s - loss: 0.8946 - accuracy: 0.7104
# Epoch 00006: val_loss improved from 1.31548 to 1.30333, saving model to tl_model_v1.weights.best.hdf5
# 100/100 [==============================] - 20s 199ms/step - loss: 0.8946 - accuracy: 0.7104 - val_loss: 1.3033 - val_accuracy: 0.6067
# Epoch 7/15
# 100/100 [==============================] - ETA: 0s - loss: 0.7755 - accuracy: 0.7497
# Epoch 00007: val_loss did not improve from 1.30333
# 100/100 [==============================] - 19s 194ms/step - loss: 0.7755 - accuracy: 0.7497 - val_loss: 1.3250 - val_accuracy: 0.6077
# Epoch 8/15
# 100/100 [==============================] - ETA: 0s - loss: 0.6514 - accuracy: 0.7904
# Epoch 00008: val_loss did not improve from 1.30333
# 100/100 [==============================] - 19s 194ms/step - loss: 0.6514 - accuracy: 0.7904 - val_loss: 1.3851 - val_accuracy: 0.6090
# Epoch 9/15
# 100/100 [==============================] - ETA: 0s - loss: 0.5415 - accuracy: 0.8248
# Epoch 00009: val_loss did not improve from 1.30333
# 100/100 [==============================] - 19s 193ms/step - loss: 0.5415 - accuracy: 0.8248 - val_loss: 1.4285 - val_accuracy: 0.6052
# Epoch 10/15
# 100/100 [==============================] - ETA: 0s - loss: 0.4344 - accuracy: 0.8606
# Epoch 00010: val_loss did not improve from 1.30333
# 100/100 [==============================] - 20s 198ms/step - loss: 0.4344 - accuracy: 0.8606 - val_loss: 1.5362 - val_accuracy: 0.6122
# Epoch 11/15
# 100/100 [==============================] - ETA: 0s - loss: 0.3418 - accuracy: 0.8897
# Epoch 00011: val_loss did not improve from 1.30333
# 100/100 [==============================] - 20s 198ms/step - loss: 0.3418 - accuracy: 0.8897 - val_loss: 1.6463 - val_accuracy: 0.6058
# Epoch 12/15
# 100/100 [==============================] - ETA: 0s - loss: 0.2779 - accuracy: 0.9110
# Epoch 00012: val_loss did not improve from 1.30333
# 100/100 [==============================] - 20s 198ms/step - loss: 0.2779 - accuracy: 0.9110 - val_loss: 1.7929 - val_accuracy: 0.6028
# Epoch 13/15
# 100/100 [==============================] - ETA: 0s - loss: 0.1907 - accuracy: 0.9397
# Epoch 00013: val_loss did not improve from 1.30333
# 100/100 [==============================] - 19s 193ms/step - loss: 0.1907 - accuracy: 0.9397 - val_loss: 1.9318 - val_accuracy: 0.5989
# Epoch 14/15
# 100/100 [==============================] - ETA: 0s - loss: 0.1472 - accuracy: 0.9542
# Epoch 00014: val_loss did not improve from 1.30333
# 100/100 [==============================] - 20s 198ms/step - loss: 0.1472 - accuracy: 0.9542 - val_loss: 2.1314 - val_accuracy: 0.6035
# Epoch 15/15
# 100/100 [==============================] - ETA: 0s - loss: 0.1034 - accuracy: 0.9686
# Epoch 00015: val_loss did not improve from 1.30333
# 100/100 [==============================] - 20s 198ms/step - loss: 0.1034 - accuracy: 0.9686 - val_loss: 2.1903 - val_accuracy: 0.6051
# 313/313 [==============================] - 2s 5ms/step - loss: 1.5620 - accuracy: 0.5148

# %%
# Esta celda fue inhabilitada debido a la exhaustividad de procesamiento; SEGUIR LOS SIGUIENTES PASOS SI SE DESEA TRABAJAR CON ESTE MODELO PREENTRENADO.
 
# Trabajar con Inception (una arquitectura CNN más moderna que VGG16) implicaría ajustar la forma de la entrada de las bases de CIFAR100 a, por lo menos, 75x75x3. 
# Para ello se sugiere hacer uso del siguiente dataset que ha aplicado un reescalamiento (256x256) a las imágenes, sin causar en nuestra máquina un consumo excesivo de recursos.
    # https://www.kaggle.com/ibraheemmoosa/cifar100-256x256
# Es necesario, si se continúa empleando Colab, importar dicho dataset a la consola virtual. Para ello, recomendamos visualizar el siguiente link donde se detalla paso a paso su subida.
    # https://www.kaggle.com/ibraheemmoosa/cifar100-256x256
# Una vez logrado, deberemos ajustar el punto de carga, el input_shape del modelo (256x256x3) e hiperparámetros (de ser necesario). 
# Enseguida, se correrá esta celda. Notése que se han predefinido las dimensiones de la entrada. 

# Transfer learning: Inception (versión 3) entrenado usando ImageNet; se usa sin su top layer, al igual que el modelo preentrenado anterior.
def init_Inception_model(summary):
  Inception_MODEL = InceptionV3(input_shape=(256, 256, 3), include_top=False, weights='imagenet')

  # Habilitar conv layers
  Inception_MODEL.trainable=True

  dropout_layer = tf.keras.layers.Dropout(rate = 0.2)
  global_average_layer = tf.keras.layers.GlobalAveragePooling2D()

  # Se sobrepone la top layer de CIFAR100 (dense de 20 neuronas, activación softmax para daterminación de clases = 1.0) junto con el model sequential de la red de transferencia
  prediction_layer = tf.keras.layers.Dense(len(Coarse_labels),activation='softmax')
  model = tf.keras.Sequential([Inception_MODEL, dropout_layer, global_average_layer, prediction_layer])

  model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.00005), loss=tf.keras.losses.sparse_categorical_crossentropy, metrics=["accuracy"])
  if summary: 
    model.summary()
  return model

Inception_MODEL = init_Inception_model(summary = True)

# %%
plt.plot(SIMPLE_MODEL_history.history['accuracy'], label='accuracy')
plt.plot(SIMPLE_MODEL_history.history['val_accuracy'], label = 'val_accuracy')
plt.plot(VGG16_MODEL_history.history['accuracy'], label='accuracy_(with VGG16)')
plt.plot(VGG16_MODEL_history.history['val_accuracy'], label = 'val_accuracy_(with VGG16)')
plt.plot(VGG16_MODEL_FT_history.history['accuracy'], label='accuracy_(with VGG16)/Fine-tuning')
plt.plot(VGG16_MODEL_FT_history.history['val_accuracy'], label = 'val_accuracy_(with VGG16)/Fine-tuning')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
#Arreglo de valores de exactitud para validación/testeo
tz_MX = pytz.timezone('America/Mexico_City')
now = datetime.now(tz_MX)
current_time = now.strftime("%d/%m/%Y a las %H:%M:%S")

historyarray.append(f'{current_time}: {round((test_acc * 100), 2)}%')

print(test_acc, historyarray)
# Out:
# 0.19259999692440033 [0, '18/11/2021 a las 13:14:47: 19.26%']

# %% [markdown]
# **Consultas y sitios web**
#
#
# ```
# 1. https://www.programiz.com/python-programming/datetime/current-datetime
# 2. https://www.tensorflow.org/tutorials/images/cnn?hl=es-419
# 3. https://www.tensorflow.org/api_docs/python/tf/keras/activations?hl=es-419)
# 4. https://gist.github.com/heyalexej/8bf688fd67d7199be4a1682b3eec7568
# 5. https://neurohive.io/en/popular-networks/vgg16/
# 6. https://www.cs.toronto.edu/~kriz/cifar.html
# 7. https://towardsdatascience.com/cifar-100-pre-processing-for-image-recognition-task-68015b43d658
# ```
